# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.default.users (
    user_id BIGINT GENERATED ALWAYS AS IDENTITY,
    name STRING NOT NULL,
    practice_name STRING NOT NULL,
    location STRING NOT NULL,
    email STRING,
    created_at TIMESTAMP
);

# %%
# %sql
INSERT INTO workspace.default.users (name, practice_name, location, email, created_at) VALUES
('Dr. John Smith', 'Cardiology Associates', 'New York, NY', 'john.smith@cardiology.com', current_timestamp()),
('Dr. Emily Davis', 'Dermatology Partners', 'Los Angeles, CA', 'emily.davis@dermpartners.com', current_timestamp()),
('Dr. Michael Brown', 'Orthopedic Care Clinic', 'Chicago, IL', 'michael.brown@orthocare.com', current_timestamp()),
('Dr. Sarah Wilson', 'Pediatric Health Group', 'Houston, TX', 'sarah.wilson@pedhealth.com', current_timestamp()),
('Dr. David Lee', 'Neurology Center', 'Phoenix, AZ', 'david.lee@neurocenter.com', current_timestamp()),
('Dr. Jessica Taylor', 'Family Medicine Practice', 'Philadelphia, PA', 'jessica.taylor@familymed.com', current_timestamp()),
('Dr. Robert Anderson', 'Internal Medicine Associates', 'San Antonio, TX', 'robert.anderson@internalmed.com', current_timestamp()),
('Dr. Lisa Martinez', 'Women''s Health Clinic', 'San Diego, CA', 'lisa.martinez@womenshealth.com', current_timestamp()),
('Dr. James Thomas', 'Emergency Care Center', 'Dallas, TX', 'james.thomas@emergcare.com', current_timestamp()),
('Dr. Jennifer Garcia', 'Mental Health Associates', 'San Jose, CA', 'jennifer.garcia@mentalhealth.com', current_timestamp());

# %%
# %sql
ALTER TABLE workspace.default.scheduled_reports ADD COLUMN user_id BIGINT;
ALTER TABLE workspace.default.reports ADD COLUMN user_id BIGINT;
